# %%
# import the pandas module
# https://pandas.pydata.org/docs/user_guide/index.html

import pandas as pd

# numpy is a standard module for simple numerical calculations
import numpy as np

import scipy.stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data_frame = pd.read_csv("Census_T40.1.txt",delimiter="\t")

# %%
data_frame=data_frame.replace("Unreliable",np.nan)

# %%
data_frame[(data_frame["Census Region Code"] == "CENS-R1") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")]
# Out:
#    Notes               Census Region Census Region Code Gender Gender Code  \
# 9    NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 10   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 11   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 12   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 13   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 14   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 15   NaN  Census Region 1: Northeast            CENS-R1   Male           M
# 16   NaN  Census Region 1: Northeast            CENS-R1   Male           M
#
#       Year  Year Code  Deaths  Population  Crude Rate
# 9   2013.0     2013.0  1703.0  27244013.0         6.3
# 10  2014.0     2014.0  2153.0  27349355.0         7.9
# 11  2015.0     2015.0  2720.0  27425256.0         9.9
# 12  2016.0     2016.0  3429.0  27402561.0        12.5
# ...

# %%
CR1_M = data_frame[(data_frame["Census Region Code"] == "CENS-R1") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR1_F = data_frame[(data_frame["Census Region Code"] == "CENS-R1") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR2_M = data_frame[(data_frame["Census Region Code"] == "CENS-R2") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR2_F = data_frame[(data_frame["Census Region Code"] == "CENS-R2") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR3_M = data_frame[(data_frame["Census Region Code"] == "CENS-R3") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR3_F = data_frame[(data_frame["Census Region Code"] == "CENS-R3") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR4_M = data_frame[(data_frame["Census Region Code"] == "CENS-R4") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CR4_F = data_frame[(data_frame["Census Region Code"] == "CENS-R4") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)

# %%
CR1_M_ante = CR1_M[CR1_M["Year"] != 2020]
CR1_M_covid = CR1_M[CR1_M["Year"] == 2020]
CR2_M_ante = CR2_M[CR2_M["Year"] != 2020]
CR2_M_covid = CR2_M[CR2_M["Year"] == 2020]
CR3_M_ante = CR3_M[CR3_M["Year"] != 2020]
CR3_M_covid = CR3_M[CR3_M["Year"] == 2020]
CR4_M_ante = CR4_M[CR4_M["Year"] != 2020]
CR4_M_covid = CR4_M[CR4_M["Year"] == 2020]
CR1_F_ante = CR1_F[CR1_F["Year"] != 2020]
CR1_F_covid = CR1_F[CR1_F["Year"] == 2020]
CR2_F_ante = CR2_F[CR2_F["Year"] != 2020]
CR2_F_covid = CR2_F[CR2_F["Year"] == 2020]
CR3_F_ante = CR3_F[CR3_F["Year"] != 2020]
CR3_F_covid = CR3_F[CR3_F["Year"] == 2020]
CR4_F_ante = CR4_F[CR4_F["Year"] != 2020]
CR4_F_covid = CR4_F[CR4_F["Year"] == 2020]

#print(CR4_F_covid)

# %%
x1=CR1_M_ante["Year"]
y1=CR1_M_ante["Crude Rate"]
x2=CR1_F_ante["Year"]
y2=CR1_F_ante["Crude Rate"]

x3=CR2_M_ante["Year"]
y3=CR2_M_ante["Crude Rate"]
x4=CR2_F_ante["Year"]
y4=CR2_F_ante["Crude Rate"]

x5=CR3_M_ante["Year"]
y5=CR3_M_ante["Crude Rate"]
x6=CR3_F_ante["Year"]
y6=CR3_F_ante["Crude Rate"]

x7=CR4_M_ante["Year"]
y7=CR4_M_ante["Crude Rate"]
x8=CR4_F_ante["Year"]
y8=CR4_F_ante["Crude Rate"]

# %%
CR1_M2=data_frame[(data_frame["Census Region Code"] == "CENS-R1") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR1_F2=data_frame[(data_frame["Census Region Code"] == "CENS-R1") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR2_M2=data_frame[(data_frame["Census Region Code"] == "CENS-R2") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR2_F2=data_frame[(data_frame["Census Region Code"] == "CENS-R2") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR3_M2=data_frame[(data_frame["Census Region Code"] == "CENS-R3") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR3_F2=data_frame[(data_frame["Census Region Code"] == "CENS-R3") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR4_M2=data_frame[(data_frame["Census Region Code"] == "CENS-R4") & (data_frame["Gender"] == "Male") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
CR4_F2=data_frame[(data_frame["Census Region Code"] == "CENS-R4") & (data_frame["Gender"] == "Female") & 
           (data_frame["Notes"] != "Total")]["Crude Rate"].astype(float)
Ratio_CR1 = CR1_M2.div(CR1_F2.values)
Ratio_CR2 = CR2_M2.div(CR2_F2.values)
Ratio_CR3 = CR3_M2.div(CR3_F2.values)
Ratio_CR4 = CR4_M2.div(CR4_F2.values)

# %%
coeffM = np.polyfit(x1, y1, 2)
yfitM = np.polyval(coeffM,x1)
resM = np.sum((y1  - yfitM)**2)
coeffF = np.polyfit(x2, y2, 2)
yfitF = np.polyval(coeffF,x2)
resF = np.sum((y2  - yfitF)**2)

#stdM = np.sqrt(resM/5)
#stdF = np.sqrt(resF/5)

stdM = np.sqrt(resM/(len(y1)-3))
stdF = np.sqrt(resF/(len(y2)-3))

gdf = pd.DataFrame({"value": [2013, 2013.5, 2014, 2014.5, 2015, 2015.5, 2016, 2016.5, 2017, 
                              2017.5, 2018, 2018.5, 2019, 2019.5, 2020]})

# %%
coeffM3 = np.polyfit(x3, y3, 2)
yfitM3 = np.polyval(coeffM3,x3)
resM3 = np.sum((y3  - yfitM3)**2)
coeffF4 = np.polyfit(x4, y4, 2)
yfitF4 = np.polyval(coeffF4,x4)
resF4 = np.sum((y4  - yfitF4)**2)

#stdM3 = np.sqrt(resM3/5)
#stdF4 = np.sqrt(resF4/5)

stdM3 = np.sqrt(resM3/(len(y3)-3))
stdF4 = np.sqrt(resF4/(len(y4)-3))

# %%
coeffM5 = np.polyfit(x5, y5, 2)
yfitM5 = np.polyval(coeffM5,x5)
resM5 = np.sum((y5  - yfitM5)**2)
coeffF6 = np.polyfit(x6, y6, 2)
yfitF6 = np.polyval(coeffF6,x6)
resF6 = np.sum((y6  - yfitF6)**2)

#stdM5 = np.sqrt(resM5/5)
#stdF6 = np.sqrt(resF6/5)

stdM5 = np.sqrt(resM5/(len(y5)-3))
stdF6 = np.sqrt(resF6/(len(y6)-3))

# %%
coeffM7 = np.polyfit(x7, y7, 2)
yfitM7 = np.polyval(coeffM7,x7)
resM7 = np.sum((y7  - yfitM7)**2)
coeffF8 = np.polyfit(x8, y8, 2)
yfitF8 = np.polyval(coeffF8,x8)
resF8 = np.sum((y8  - yfitF8)**2)

#stdM7 = np.sqrt(resM7/5)
#stdF8 = np.sqrt(resF8/5)

stdM7 = np.sqrt(resM7/(len(y7)-3))
stdF8 = np.sqrt(resF8/(len(y8)-3))

# %%
plt.plot(gdf, np.polyval(coeffM,gdf), color='tab:blue')
plt.scatter(x1,y1, color='tab:blue')
plt.scatter(2020.0, CR1_M_covid["Crude Rate"], color='tab:blue')
plt.scatter(2020.0, np.polyval(coeffM,2020), s=100, edgecolors='tab:blue', facecolors='none')

plt.plot(gdf, np.polyval(coeffF,gdf), color='tab:pink')
plt.scatter(x2,y2, color='tab:pink')
#plt.legend(["females", "males"], frameon=False)
plt.scatter(2020.0, CR1_F_covid["Crude Rate"],color='tab:pink')
plt.scatter(2020.0, np.polyval(coeffF,2020), s=100, edgecolors='tab:pink', facecolors='none')

#plt.legend(["male", "female"], frameon=False, fontsize = 14)

plt.plot(gdf, np.polyval(coeffF,gdf)+3*stdF, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffF,gdf)-3*stdF, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM,gdf)+3*stdM, color='tab:blue', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM,gdf)-3*stdM, color='tab:blue', linestyle='dashed')

print('percent off female = ',(CR1_F_covid["Crude Rate"]/np.polyval(coeffF,2020)-1)*100)
print('percent off male = ',(CR1_M_covid["Crude Rate"]/np.polyval(coeffM,2020)-1)*100)
#print(CF2_covid["Crude Rate"])
#print(np.polyval(coeffF,2020))
plt.suptitle('heroin (T40.1) Northeast', fontsize=20)
#plt.xlabel("year", fontsize =14)
plt.ylabel("crude rate", fontsize =14)
plt.yticks(np.arange(0, 16, 5.0))
plt.yticks(fontsize=12, rotation=0)
plt.xticks(fontsize=12, rotation=0)

plt.savefig('T40.1_Northeast.svg')

plt.figure()
plt.plot(gdf, np.polyval(coeffM3,gdf), color='tab:blue')
plt.scatter(x3,y3, color='tab:blue')
plt.scatter(2020.0, CR2_M_covid["Crude Rate"], color='tab:blue')
plt.scatter(2020.0, np.polyval(coeffM3,2020), s=100, edgecolors='tab:blue', facecolors='none')

plt.plot(gdf, np.polyval(coeffF4,gdf), color='tab:pink')
plt.scatter(x4,y4, color='tab:pink')
#plt.legend(["male", "female"], frameon=False)
plt.scatter(2020.0, CR2_F_covid["Crude Rate"],color='tab:pink')
plt.scatter(2020.0, np.polyval(coeffF4,2020), s=100, edgecolors='tab:pink', facecolors='none')

#plt.legend(["male", "female"], frameon=False, fontsize = 14)

plt.plot(gdf, np.polyval(coeffF4,gdf)+3*stdF4, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffF4,gdf)-3*stdF4, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM3,gdf)+3*stdM3, color='tab:blue', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM3,gdf)-3*stdM3, color='tab:blue', linestyle='dashed')

print('percent off female = ',(CR2_F_covid["Crude Rate"]/np.polyval(coeffF4,2020)-1)*100)
print('percent off male = ',(CR2_M_covid["Crude Rate"]/np.polyval(coeffM3,2020)-1)*100)
#print(CF2_covid["Crude Rate"])
#print(np.polyval(coeffF,2020))
plt.suptitle('heroin (T40.1) Midwest', fontsize=20)
#plt.xlabel("year", fontsize =14)
plt.ylabel("crude rate", fontsize =14)
plt.yticks(np.arange(0, 12, 5.0))
plt.yticks(fontsize=12, rotation=0)
plt.xticks(fontsize=12, rotation=0)

plt.savefig('T40.1_Midwest.svg')

plt.figure()
plt.plot(gdf, np.polyval(coeffM5,gdf), color='tab:blue')
plt.scatter(x5,y5, color='tab:blue')
plt.scatter(2020.0, CR3_M_covid["Crude Rate"], color='tab:blue')
plt.scatter(2020.0, np.polyval(coeffM5,2020), s=100, edgecolors='tab:blue', facecolors='none')

plt.plot(gdf, np.polyval(coeffF6,gdf), color='tab:pink')
plt.scatter(x6,y6, color='tab:pink')
#plt.legend(["females", "males"], frameon=False)
plt.scatter(2020.0, CR3_F_covid["Crude Rate"],color='tab:pink')
plt.scatter(2020.0, np.polyval(coeffF6,2020), s=100, edgecolors='tab:pink', facecolors='none')

#plt.legend(["male", "female"], frameon=False, fontsize = 14)

plt.plot(gdf, np.polyval(coeffF6,gdf)+3*stdF6, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffF6,gdf)-3*stdF6, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM5,gdf)+3*stdM5, color='tab:blue', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM5,gdf)-3*stdM5, color='tab:blue', linestyle='dashed')

print('percent off female = ',(CR3_F_covid["Crude Rate"]/np.polyval(coeffF6,2020)-1)*100)
print('percent off male = ',(CR3_M_covid["Crude Rate"]/np.polyval(coeffM5,2020)-1)*100)
#print(CF2_covid["Crude Rate"])
#print(np.polyval(coeffF,2020))
plt.suptitle('heroin (T40.1) South', fontsize=20)
#plt.xlabel("year", fontsize =14)
plt.ylabel("crude rate", fontsize =14)
plt.yticks(np.arange(0, 8, 2.0))
plt.yticks(fontsize=12, rotation=0)
plt.xticks(fontsize=12, rotation=0)

plt.savefig('T40.1_South.svg')

plt.figure()
plt.plot(gdf, np.polyval(coeffM7,gdf), color='tab:blue')
plt.scatter(x7,y7, color='tab:blue')
plt.scatter(2020.0, CR4_M_covid["Crude Rate"], color='tab:blue')
plt.scatter(2020.0, np.polyval(coeffM7,2020), s=100, edgecolors='tab:blue', facecolors='none')

plt.plot(gdf, np.polyval(coeffF8,gdf), color='tab:pink')
plt.scatter(x8,y8, color='tab:pink')
plt.scatter(2020.0, CR4_F_covid["Crude Rate"],color='tab:pink')
plt.scatter(2020.0, np.polyval(coeffF8,2020), s=100, edgecolors='tab:pink', facecolors='none')

#plt.legend(["male", "female"], frameon=False, fontsize = 14)

plt.plot(gdf, np.polyval(coeffF8,gdf)+3*stdF8, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffF8,gdf)-3*stdF8, color='tab:pink', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM7,gdf)+3*stdM7, color='tab:blue', linestyle='dashed')
plt.plot(gdf, np.polyval(coeffM7,gdf)-3*stdM7, color='tab:blue', linestyle='dashed')

print('percent off female = ',(CR4_F_covid["Crude Rate"]/np.polyval(coeffF8,2020)-1)*100)
print('percent off male = ',(CR4_M_covid["Crude Rate"]/np.polyval(coeffM7,2020)-1)*100)
#print(CF2_covid["Crude Rate"])
#print(np.polyval(coeffF,2020))
#plt.suptitle('T40.1 (heroin) West', fontsize=15)
plt.suptitle('heroin (T40.1) West', fontsize=20)
#plt.xlabel("year", fontsize =14)
plt.ylabel("crude rate", fontsize =14)
plt.yticks(np.arange(0, 8, 2.0))
plt.yticks(fontsize=12, rotation=0)
plt.xticks(fontsize=12, rotation=0)

plt.savefig('T40.1_West.svg')
# Out:
# percent off female =  7   -12.077295
# Name: Crude Rate, dtype: float64
# percent off male =  16    1.217656
# Name: Crude Rate, dtype: float64
# percent off female =  26    31.25
# Name: Crude Rate, dtype: float64
# percent off male =  35    48.561151
# Name: Crude Rate, dtype: float64
# percent off female =  45    10.833333
# Name: Crude Rate, dtype: float64
# percent off male =  54    6.779661
# Name: Crude Rate, dtype: float64
# percent off female =  64    5.660377
# Name: Crude Rate, dtype: float64
# percent off male =  73    1.643836
# Name: Crude Rate, dtype: float64
