# %%
# import the pandas module
# https://pandas.pydata.org/docs/user_guide/index.html

import pandas as pd

# numpy is a standard module for simple numerical calculations
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data_frame = pd.read_csv("T43.6_BWM.txt",delimiter="\t")
pd.set_option('display.max_rows', None)

# %% [markdown]
# We replace "Unreliable" by NaN.

# %%
data_frame=data_frame.replace("Unreliable",np.nan)
data_frame=data_frame.replace("Suppressed",np.nan)

# %%
state = 'West Virginia'
state2 = "District of Columbia"
state3= 'Illinois'
state4 = "Maryland"
state5= 'Delaware'

# %%
strCF1 = str(state)
strCF2 = str(state2)
strCF3 = str(state3)
strCF4 = str(state4)
strCF5 = str(state5)

# %%
data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & ((data_frame["Year"] == 2020))] 

#data_frame[(data_frame["Race"] == "Black or African American")& 
#           (data_frame["Notes"] != "Total") & ((data_frame["Year"] == 2020) | (data_frame["Year"] == 2019))]
# Out:
#      Notes                 State  State Code Gender Gender Code  \
# 23     NaN               Alabama         1.0   Male           M
# 55     NaN                Alaska         2.0   Male           M
# 87     NaN               Arizona         4.0   Male           M
# 119    NaN              Arkansas         5.0   Male           M
# 151    NaN            California         6.0   Male           M
# 183    NaN              Colorado         8.0   Male           M
# 215    NaN           Connecticut         9.0   Male           M
# 247    NaN              Delaware        10.0   Male           M
# 279    NaN  District of Columbia        11.0   Male           M
# 311    NaN               Florida        12.0   Male           M
# 343    NaN               Georgia        13.0   Male           M
# 375    NaN                Hawaii        15.0   Male           M
# 407    NaN                 Idaho        16.0   Male           M
# 439    NaN              Illinois        17.0   Male           M
# ...

# %%
data_frame[((data_frame["Race"] == "White")) & 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2020)]

#data_frame[((data_frame["Race"] == "Black or African American") | (data_frame["Race"] == "White")) & 
#           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2020)]
# Out:
#      Notes                 State  State Code Gender Gender Code   Race  \
# 31     NaN               Alabama         1.0   Male           M  White
# 63     NaN                Alaska         2.0   Male           M  White
# 95     NaN               Arizona         4.0   Male           M  White
# 127    NaN              Arkansas         5.0   Male           M  White
# 159    NaN            California         6.0   Male           M  White
# 191    NaN              Colorado         8.0   Male           M  White
# 223    NaN           Connecticut         9.0   Male           M  White
# 255    NaN              Delaware        10.0   Male           M  White
# 287    NaN  District of Columbia        11.0   Male           M  White
# 319    NaN               Florida        12.0   Male           M  White
# 351    NaN               Georgia        13.0   Male           M  White
# 383    NaN                Hawaii        15.0   Male           M  White
# ...

# %%
data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2020)]
# Out:
#      Notes                 State  State Code Gender Gender Code  \
# 23     NaN               Alabama         1.0   Male           M
# 55     NaN                Alaska         2.0   Male           M
# 87     NaN               Arizona         4.0   Male           M
# 119    NaN              Arkansas         5.0   Male           M
# 151    NaN            California         6.0   Male           M
# 183    NaN              Colorado         8.0   Male           M
# 215    NaN           Connecticut         9.0   Male           M
# 247    NaN              Delaware        10.0   Male           M
# 279    NaN  District of Columbia        11.0   Male           M
# 311    NaN               Florida        12.0   Male           M
# 343    NaN               Georgia        13.0   Male           M
# 375    NaN                Hawaii        15.0   Male           M
# 407    NaN                 Idaho        16.0   Male           M
# 439    NaN              Illinois        17.0   Male           M
# ...

# %%
data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total")& (data_frame["Year"] == 2020)]
# Out:
#      Notes                 State  State Code Gender Gender Code   Race  \
# 31     NaN               Alabama         1.0   Male           M  White
# 63     NaN                Alaska         2.0   Male           M  White
# 95     NaN               Arizona         4.0   Male           M  White
# 127    NaN              Arkansas         5.0   Male           M  White
# 159    NaN            California         6.0   Male           M  White
# 191    NaN              Colorado         8.0   Male           M  White
# 223    NaN           Connecticut         9.0   Male           M  White
# 255    NaN              Delaware        10.0   Male           M  White
# 287    NaN  District of Columbia        11.0   Male           M  White
# 319    NaN               Florida        12.0   Male           M  White
# 351    NaN               Georgia        13.0   Male           M  White
# 383    NaN                Hawaii        15.0   Male           M  White
# ...

# %%
data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2019)]
# Out:
#      Notes                 State  State Code Gender Gender Code   Race  \
# 30     NaN               Alabama         1.0   Male           M  White
# 62     NaN                Alaska         2.0   Male           M  White
# 94     NaN               Arizona         4.0   Male           M  White
# 126    NaN              Arkansas         5.0   Male           M  White
# 158    NaN            California         6.0   Male           M  White
# 190    NaN              Colorado         8.0   Male           M  White
# 222    NaN           Connecticut         9.0   Male           M  White
# 254    NaN              Delaware        10.0   Male           M  White
# 286    NaN  District of Columbia        11.0   Male           M  White
# 318    NaN               Florida        12.0   Male           M  White
# 350    NaN               Georgia        13.0   Male           M  White
# 382    NaN                Hawaii        15.0   Male           M  White
# ...

# %%
CM2b_2020 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2020)]
CM2w_2020 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2020)]
CM2b_2019 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2019)]
CM2w_2019 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2019)]
CM2b_2018 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2018)]
CM2w_2018 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2018)]
CM2b_2017 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2017)]
CM2w_2017 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["Year"] == 2017)]

# %%
bm20 = {'States': CM2b_2020["State"], 'Crude Rate': CM2b_2020["Crude Rate"].astype(float)}
#dbm20 = pd.DataFrame(bm20, columns = ['States','Crude Rate'])
dbm20 = pd.DataFrame(bm20, columns = ['Crude Rate'], index=['State'])
dbm20s = dbm20.sort_values(by=['Crude Rate'], ascending=False)
wm20 = {'States': CM2w_2020["State"], 'Crude Rate': CM2w_2020["Crude Rate"].astype(float)}
dwm20 = pd.DataFrame(wm20, columns = ['States','Crude Rate'])
dwm20s = dwm20.sort_values(by=['Crude Rate'], ascending=False)
bm19 = {'States': CM2b_2019["State"], 'Crude Rate': CM2b_2019["Crude Rate"].astype(float)}
dbm19 = pd.DataFrame(bm19, columns = ['States','Crude Rate'])
dbm19s = dbm19.sort_values(by=['Crude Rate'], ascending=False)
wm19 = {'States': CM2w_2019["State"], 'Crude Rate': CM2w_2019["Crude Rate"].astype(float)}
dwm19 = pd.DataFrame(wm19, columns = ['States','Crude Rate'])
dwm19s = dwm19.sort_values(by=['Crude Rate'], ascending=False)
#print(dbm20s.iloc[0:5])
#print(dwm20s.iloc[0:5])
#print(dbm19s.iloc[0:5])
#print(dwm19s.iloc[0:5])

# %%
bm18 = {'States': CM2b_2018["State"], 'Crude Rate': CM2b_2018["Crude Rate"].astype(float)}
dbm18 = pd.DataFrame(bm18, columns = ['States','Crude Rate'])
dbm18s = dbm18.sort_values(by=['Crude Rate'], ascending=False)
wm18 = {'States': CM2w_2018["State"], 'Crude Rate': CM2w_2018["Crude Rate"].astype(float)}
dwm18 = pd.DataFrame(wm18, columns = ['States','Crude Rate'])
dwm18s = dwm18.sort_values(by=['Crude Rate'], ascending=False)
bm17 = {'States': CM2b_2019["State"], 'Crude Rate': CM2b_2018["Crude Rate"].astype(float)}
dbm17 = pd.DataFrame(bm17, columns = ['States','Crude Rate'])
dbm17s = dbm17.sort_values(by=['Crude Rate'], ascending=False)
wm17 = {'States': CM2w_2019["State"], 'Crude Rate': CM2w_2018["Crude Rate"].astype(float)}
dwm17 = pd.DataFrame(wm17, columns = ['States','Crude Rate'])
dwm17s = dwm17.sort_values(by=['Crude Rate'], ascending=False)
#print(dbf20s.iloc[0:5])
#print(dwf20s.iloc[0:5])
#print(dbf19s.iloc[0:5])
#print(dwf19s.iloc[0:5])

# %%
#datadrugs = {'Black Male 2020': CF2b_2020["Crude Rate"].astype(float).values,    
#            'Black Male 2019': CF2b_2019["Crude Rate"].astype(float).values,
#             'States':CF2b_2020['State']}

#df = pd.DataFrame(datadrugs,columns=['Black Male 2020',
#                                     'Black Male 2019'],                index = CF2b_2020['State'])


#dbm20s2=dbm20s.dropna()
#dbm20s2.plot.barh(figsize=(18, 18))
#plt.title('Store Inventory')
#plt.ylabel('State')
#plt.xlabel('Crude Rate')
#plt.show()

# %%
CM2b1 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["State"] == state) &
                 (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float) 
CM2b3 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total")&  (data_frame["State"] == state3)&
                (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float)
CMb1 = data_frame[(data_frame["State"] == state) &
                  (data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CMb3 = data_frame[(data_frame["Race"] == "Black or African American")& 
                  (data_frame["State"] == state3) & 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CM2b1_covid = data_frame[(data_frame["Race"] == "Black or African American")&
                         (data_frame["State"] == state) & 
           (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)
CM2b3_covid = data_frame[ (data_frame["Race"] == "Black or African American")& 
                         (data_frame["State"] == state3) & 
                (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)

CM2b2 = data_frame[(data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total") & (data_frame["State"] == state2) &
                 (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float) 
CM2b4 = data_frame[ (data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total")& (data_frame["State"] == state4) &
                (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float)
CMb2 = data_frame[(data_frame["State"] == state2) &
                  (data_frame["Race"] == "Black or African American")& 
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CMb4 = data_frame[ (data_frame["Race"] == "Black or African American")& 
                  (data_frame["State"] == state4) &
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CM2b2_covid = data_frame[ (data_frame["Race"] == "Black or African American")&
                        (data_frame["State"] == state2) &
           (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)
CM2b4_covid = data_frame[(data_frame["Race"] == "Black or African American")& 
                         (data_frame["State"] == state4) &
                (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)

# %%
CM2w1 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total") & (data_frame["State"] == state) &
                 (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float) 
CM2w3 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total")& (data_frame["State"] == state3) &
                (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float)
CMw1 = data_frame[(data_frame["Race"] == "White")& 
                  (data_frame["State"] == state) &
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CMw3 = data_frame[(data_frame["Race"] == "White")& 
                  (data_frame["State"] == state3) &
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CM2w1_covid = data_frame[(data_frame["Race"] == "White")& 
                         (data_frame["State"] == state) &
           (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)
CM2w3_covid = data_frame[ (data_frame["Race"] == "White")& 
                         (data_frame["State"] == state3) &
                (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)

CM2w2 = data_frame[(data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total")& (data_frame["State"] == state2) &
                 (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float) 
CM2w4 = data_frame[ (data_frame["Race"] == "White")& 
           (data_frame["Notes"] != "Total")&  (data_frame["State"] == state4) &
                (data_frame["Year"] != 2020.0)][["Year", "Crude Rate"]].astype(float)
CMw2 = data_frame[(data_frame["Race"] == "White")& 
                   (data_frame["State"] == state2) &
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CMw4 = data_frame[ (data_frame["Race"] == "White")& 
                   (data_frame["State"] == state4) &
           (data_frame["Notes"] != "Total")][["Year", "Crude Rate"]].astype(float)
CM2w2_covid = data_frame[(data_frame["Race"] == "White")& 
                          (data_frame["State"] == state2) &
           (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)
CM2w4_covid = data_frame[ (data_frame["Race"] == "White")& 
                          (data_frame["State"] == state4) &
                         (data_frame["Year"] == 2020.0)][["Year", "Crude Rate"]].astype(float)

# %%
CM2b1=CM2b1.dropna()
CM2b2=CM2b2.dropna()
CM2b3=CM2b3.dropna()
CM2b4=CM2b4.dropna()
CM2w1=CM2w1.dropna()
CM2w2=CM2w2.dropna()
CM2w3=CM2w3.dropna()
CM2w4=CM2w4.dropna()

# %%
plt.figure()
x1b1=CM2b1["Year"]
x1cb1=CMb1["Year"]
y1b1=CM2b1["Crude Rate"]
plt.plot(x1b1, y1b1)
plt.scatter(x1b1, y1b1, color="tab:blue")
plt.scatter(2020.0, CM2b1_covid["Crude Rate"], color="tab:blue")
x1b2=CM2b2["Year"]
x1cb2=CMb2["Year"]
y1b2=CM2b2["Crude Rate"]
plt.plot(x1b2, y1b2)
plt.scatter(x1b2, y1b2, color="tab:orange")
plt.scatter(2020.0, CM2b2_covid["Crude Rate"], color="tab:orange")
plt.suptitle('T43.6 Male Black', fontsize=15)
plt.legend([strCF1,strCF2])


plt.figure()
x2b3=CM2b3["Year"]
x2cb3=CMb3["Year"]
y2b3=CM2b3["Crude Rate"]
plt.plot(x2b3, y2b3)
plt.scatter(x2b3, y2b3, color="tab:blue")
plt.scatter(2020.0, CM2b3_covid["Crude Rate"], color="tab:blue")
x2b4=CM2b4["Year"]
x2cb4=CMb4["Year"]
y2b4=CM2b4["Crude Rate"]
plt.plot(x2b4, y2b4)
plt.scatter(x2b4, y2b4, color="tab:orange")
plt.scatter(2020.0, CM2b4_covid["Crude Rate"], color="tab:orange")
plt.suptitle('T43.6 Male Black', fontsize=15)
plt.legend([strCF3, strCF4])

plt.figure()
x1w1=CM2w1["Year"]
x1cw1=CMw1["Year"]
y1w1=CM2w1["Crude Rate"]
plt.plot(x1w1, y1w1)
plt.scatter(x1w1, y1w1, color="tab:blue")
plt.scatter(2020.0, CM2w1_covid["Crude Rate"], color="tab:blue")
x1w2=CM2w2["Year"]
x1cw2=CMw2["Year"]
y1w2=CM2w2["Crude Rate"]
plt.plot(x1w2, y1w2)
plt.scatter(x1w2, y1w2,  color="tab:orange")
plt.scatter(2020.0, CM2w2_covid["Crude Rate"],  color="tab:orange")
plt.suptitle('T43.6 Male White', fontsize=15)
plt.legend([strCF1, strCF2])

plt.figure()
x2w3=CM2w3["Year"]
x2cw3=CMw3["Year"]
y2w3=CM2w3["Crude Rate"]
plt.plot(x2w3, y2w3, color="tab:blue")
plt.scatter(x2w3, y2w3, color="tab:blue")
plt.scatter(2020.0, CM2w3_covid["Crude Rate"], color="tab:blue")
x2w4=CM2w4["Year"]
x2cw4=CMw4["Year"]
y2w4=CM2w4["Crude Rate"]
plt.plot(x2w4, y2w4, color="tab:orange")
plt.scatter(x2w4, y2w4, color="tab:orange")
plt.scatter(2020.0, CM2w4_covid["Crude Rate"], color="tab:orange")
plt.suptitle('T43.6 Male White', fontsize=15)
plt.legend([strCF3, strCF4])

plt.figure()
plt.plot(x1b1, y1b1,  color="tab:blue")
plt.scatter(x1b1, y1b1, color="tab:blue")
plt.scatter(2020.0, CM2b1_covid["Crude Rate"], color="tab:blue")
plt.plot(x1w1, y1w1, color="tab:orange")
plt.scatter(x1w1, y1w1, color="tab:orange")
plt.scatter(2020.0, CM2w1_covid["Crude Rate"], color="tab:orange")
plt.plot(x1b2, y1b2, color="tab:red")
plt.scatter(x1b2, y1b2, color="tab:red")
plt.scatter(2020.0, CM2b2_covid["Crude Rate"], color="tab:red")
plt.plot(x1w2, y1w2, color="tab:green")
plt.scatter(x1w2, y1w2, color="tab:green")
plt.scatter(2020.0, CM2w2_covid["Crude Rate"], color="tab:green")
plt.suptitle('T43.6 Males', fontsize=15)
plt.legend(["black " + strCF1, "white " + strCF1, "black " + strCF2,  "white " + strCF2 ])


plt.figure()
plt.plot(x2b3, y2b3,  color="tab:blue")
plt.scatter(x2b3, y2b3, color="tab:blue")
plt.scatter(2020.0, CM2b3_covid["Crude Rate"], color="tab:blue")
plt.plot(x2w3, y2w3, color= "tab:orange")
plt.scatter(x2w3, y2w3, color="tab:orange")
plt.scatter(2020.0, CM2w3_covid["Crude Rate"], color="tab:orange")
plt.plot(x2b4, y2b4, color="tab:red")
plt.scatter(x2b4, y2b4, color="tab:red")
plt.scatter(2020.0, CM2b4_covid["Crude Rate"], color="tab:red")
plt.plot(x2w4, y2w4, color="tab:green")
plt.scatter(x2w4, y2w4, color="tab:green")
plt.scatter(2020.0, CM2w4_covid["Crude Rate"], color="tab:green")
plt.suptitle('T43.6 Males', fontsize=15)
plt.legend(["black " + strCF3, "white " + strCF3, "black " + strCF4,  "white " + strCF4 ])

# %%
b2w19r = CM2b_2019["Crude Rate"].astype(float).div(CM2w_2019["Crude Rate"].astype(float).values)
#pctchg = pctchg.dropna()
states19 = CM2b_2019["State"]

b2w20r = CM2b_2020["Crude Rate"].astype(float).div(CM2w_2020["Crude Rate"].astype(float).values)
#pctchg = pctchg.dropna()
states20 = CM2b_2020["State"]

datar19 = {'States': states19, 'Ratio19': b2w19r}
dr19 = pd.DataFrame(datar19, columns = ['States','Ratio19'])
dr19s = dr19.sort_values(by=['Ratio19'], ascending=True)

datar20 = {'States': states20, 'Ratio20': b2w20r}
dr20 = pd.DataFrame(datar20, columns = ['States','Ratio20'])
dr20s = dr20.sort_values(by=['Ratio20'], ascending=True)


plt.figure(figsize=(10, 8))
plt.xticks(rotation=90)
plt.scatter(states19, b2w19r)
plt.scatter(states19, b2w20r)
plt.suptitle('T43.6 Black to White males', fontsize=15)

plt.figure(figsize=(10, 8))
plt.xticks(rotation=90)
plt.scatter(states19, b2w20r.values-b2w19r.values)
hlines=[0]
plt.hlines(hlines, 1, xmax = 50, color='g')

# %%
plt.figure(figsize=(10, 8))
plt.suptitle('T43.6 Differences 2020-2019 Black to White Males', fontsize=15)
plt.xticks(rotation=90)
plt.scatter(dr20s['States'].astype(str), dr20s['Ratio20'])
plt.scatter(dr20s['States'].astype(str), 1/dr20s['Ratio20'])
hlines=[1]
plt.hlines(hlines, 1, xmax = 33, color='g')

#print(dr20s)

#plt.figure(figsize=(10, 8))
#plt.suptitle('T40.4 Differences 2020-2019 Black to White Males', fontsize=15)
#plt.xticks(rotation=90)
plt.scatter(dr19s['States'].astype(str), dr19s['Ratio19'])
plt.scatter(dr19s['States'].astype(str), 1/dr19s['Ratio19'])
hlines=[1]
plt.hlines(hlines, 1, xmax = 33, color='g')

#print(dr20s, dr19s)

# %%
#print(dr20, dr19)

# %%
Rb2w19r = CM2b_2019["Crude Rate"].astype(float).div(CM2w_2019["Crude Rate"].astype(float).values)
#pctchg = pctchg.dropna()
Rstates19 = CM2b_2019["State"]

Rb2w20r = CM2b_2020["Crude Rate"].astype(float).div(CM2w_2020["Crude Rate"].astype(float).values)
#pctchg = pctchg.dropna()
Rstates20 = CM2b_2020["State"]

Rdatar19 = {'States': Rstates19, 'Ratio19': Rb2w19r}
Rdr19 = pd.DataFrame(Rdatar19, columns = ['States','Ratio19'])
Rdr19s = Rdr19.sort_values(by=['Ratio19'], ascending=True)

Rdatar20 = {'States': Rstates20, 'Ratio20': Rb2w20r}
Rdr20 = pd.DataFrame(Rdatar20, columns = ['States','Ratio20'])
Rdr20s = Rdr20.sort_values(by=['Ratio20'], ascending=True)


plt.figure(figsize=(10, 8))
plt.xticks(rotation=90)
plt.scatter(Rstates19, Rb2w19r)
plt.scatter(Rstates19, Rb2w20r)
plt.suptitle('T43.6 Black to White Males', fontsize=15)

plt.figure(figsize=(10, 8))
plt.xticks(rotation=90)
plt.scatter(Rstates19, Rb2w20r.values-Rb2w19r.values)
hlines=[0]
plt.hlines(hlines, 1, xmax = 50, color='g')

# %%
plt.figure(figsize=(10, 8))
plt.suptitle('T43.6 Differences 2020-2019 Black to White Males', fontsize=15)
plt.xticks(rotation=90)
plt.scatter(Rdr20s['States'].astype(str), Rdr20s['Ratio20'])
plt.scatter(Rdr20s['States'].astype(str), 1/Rdr20s['Ratio20'])
hlines=[1]
plt.hlines(hlines, 1, xmax = 30, color='g')

#print(dr20s)

# %%
#print(CF2b_2019["State"], CF2b_2019["Crude Rate"].astype(float).div(CF2w_2019["Crude Rate"].astype(float).values))
#print(CM2b_2019["Crude Rate"].astype(float).div(CM2w_2019["Crude Rate"].astype(float).values))

# %%
left19 = pd.DataFrame({"States": CM2w_2019["State"].astype(str), "White": CM2w_2019["Crude Rate"].astype(float)})
right19 = pd.DataFrame({"States": CM2b_2019["State"].astype(str), "Black": CM2b_2019["Crude Rate"].astype(float)})

result19 = pd.merge(left19, right19, on = "States")
result219 = pd.merge(left19, right19, how = 'right')
#result19 = result19.dropna(thresh=2)

left20 = pd.DataFrame({"States": CM2w_2020["State"].astype(str), "White": CM2w_2020["Crude Rate"].astype(float)})
right20 = pd.DataFrame({"States": CM2b_2020["State"].astype(str), "Black": CM2b_2020["Crude Rate"].astype(float)})

result20 = pd.merge(left20, right20, on = "States")
result220 = pd.merge(left20, right20, how = 'right')
#result20= result20.dropna(thresh=2)

result19.loc[::-1]
#print(resultF.loc[::-1])

df19 = pd.DataFrame(result19.loc[::-1])
df19.index = df19['States']
ax = df19.plot(kind='barh', figsize=(4, 14),  color={"White": "orange", "Black": "black"}, width = 0.8, 
         fontsize=14)
plt.suptitle('T43.6 (methamphetamines) 2019', fontsize = 20)
plt.xlabel('Crude Rate', fontsize = 14)
plt.ylabel('States', fontsize = 14)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels),framealpha=0.0, fontsize = 14)

#plt.yticks(fontsize=14)
#plt.xticks(fontsize=14)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
plt.xlim((0,140))
plt.savefig('T43.6_2019_Race.svg')

# %%
df20 = pd.DataFrame(result20.loc[::-1])
df20.index = df20['States']
ax2 = df20.plot(kind='barh', figsize=(4, 14),  color={"White": "orange", "Black": "black"}, width = 0.8, 
         fontsize=14)
plt.suptitle('T43.6 (methamphetamines) 2020', fontsize = 20)
plt.xlabel('Crude Rate', fontsize = 14)
plt.ylabel('States', fontsize = 14)
#plt.yticks(fontsize=14)
#plt.xticks(fontsize=14)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(True)
ax2.spines['left'].set_visible(True)

handles, labels = ax2.get_legend_handles_labels()
ax2.legend(reversed(handles), reversed(labels),framealpha=0.0, fontsize = 14)

plt.xlim((0,140))
plt.savefig('T43.6_2020_Race.svg')
